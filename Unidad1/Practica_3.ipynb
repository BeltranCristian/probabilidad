# %% [markdown]
# <a href="https://colab.research.google.com/github/BeltranCristian/probabilidad/blob/main/Unidad1/Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y Estadistica**
# ##Grupo: 2y
# ##Unidad 1
# Docente: Jose Gabriel Rodriguez Rivas
#
# Alumno: Cristian Emmanuel Beltran Luevanos
#
# **Practica 3: Tabla de frecuencias y regla de Sturges..**

# %%
import random
edades = []
for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [60, 53, 58, 69, 51, 68, 26, 24, 22, 58, 48, 70, 51, 31, 26, 67, 23, 58, 48, 62, 22, 32, 31, 48, 30, 34, 25, 20, 57, 29, 67, 18, 45, 64, 45, 18, 36, 48, 42, 25, 45, 52, 31, 57, 64, 31, 40, 67, 25, 70, 69, 70, 54, 48, 46, 60, 61, 39, 57, 20, 52, 47, 33, 50, 20, 36, 36, 31, 69, 64, 29, 29, 65, 21, 49, 19, 60, 33, 18, 24, 34, 53, 22, 28, 20, 35, 45, 22, 51, 38, 21, 30, 54, 35, 40, 64, 19, 64, 31, 56]

# %%
import pandas as pd
df = pd.DataFrame(edades, columns=['edades'])
df.head()
# Out:
#    edades
# 0      60
# 1      53
# 2      58
# 3      69
# 4      51

# %%
tabla_Frecuencias = df['edades'].value_counts().reset_index()
tabla_Frecuencias.columns = ['Edad', 'Frecuencia']
tabla_Frecuencias = tabla_Frecuencias.sort_values(by='Edad')

print("Tabla de distribucion de frecuencias: ")
tabla_Frecuencias
# Out:
# Tabla de distribucion de frecuencias:
#     Edad  Frecuencia
# 15    18           3
# 20    19           2
# 4     20           4
# 24    21           2
# 3     22           4
# 30    23           1
# 17    24           2
# 14    25           3
# 18    26           2
# 41    28           1
# 13    29           3
# 23    30           2
# 0     31           6
# 33    32           1
# 25    33           2
# 21    34           2
# 28    35           2
# 12    36           3
# 42    38           1
# 38    39           1
# 27    40           2
# 32    42           1
# 5     45           4
# 35    46           1
# 37    47           1
# 1     48           5
# 40    49           1
# 36    50           1
# 7     51           3
# 22    52           2
# 19    53           2
# 26    54           2
# 43    56           1
# 16    57           3
# 10    58           3
# 11    60           3
# 34    61           1
# 31    62           1
# 2     64           5
# 39    65           1
# 8     67           3
# 29    68           1
# 9     69           3
# 6     70           3

# %%
tabla_Frecuencias['Frec Relativa'] = tabla_Frecuencias['Frecuencia'] / 100
tabla_Frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 15    18           3           0.03
# 20    19           2           0.02
# 4     20           4           0.04
# 24    21           2           0.02
# 3     22           4           0.04
# 30    23           1           0.01
# 17    24           2           0.02
# 14    25           3           0.03
# 18    26           2           0.02
# 41    28           1           0.01
# 13    29           3           0.03
# 23    30           2           0.02
# 0     31           6           0.06
# 33    32           1           0.01
# 25    33           2           0.02
# 21    34           2           0.02
# 28    35           2           0.02
# 12    36           3           0.03
# 42    38           1           0.01
# 38    39           1           0.01
# 27    40           2           0.02
# 32    42           1           0.01
# 5     45           4           0.04
# 35    46           1           0.01
# 37    47           1           0.01
# 1     48           5           0.05
# 40    49           1           0.01
# 36    50           1           0.01
# 7     51           3           0.03
# 22    52           2           0.02
# 19    53           2           0.02
# 26    54           2           0.02
# 43    56           1           0.01
# 16    57           3           0.03
# 10    58           3           0.03
# 11    60           3           0.03
# 34    61           1           0.01
# 31    62           1           0.01
# 2     64           5           0.05
# 39    65           1           0.01
# 8     67           3           0.03
# 29    68           1           0.01
# 9     69           3           0.03
# 6     70           3           0.03

# %%
tabla_Frecuencias['Frec Porcentual'] = tabla_Frecuencias['Frecuencia'] / 100 * 100
tabla_Frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 15    18           3           0.03              3.0
# 20    19           2           0.02              2.0
# 4     20           4           0.04              4.0
# 24    21           2           0.02              2.0
# 3     22           4           0.04              4.0
# 30    23           1           0.01              1.0
# 17    24           2           0.02              2.0
# 14    25           3           0.03              3.0
# 18    26           2           0.02              2.0
# 41    28           1           0.01              1.0
# 13    29           3           0.03              3.0
# 23    30           2           0.02              2.0
# 0     31           6           0.06              6.0
# 33    32           1           0.01              1.0
# 25    33           2           0.02              2.0
# 21    34           2           0.02              2.0
# 28    35           2           0.02              2.0
# 12    36           3           0.03              3.0
# 42    38           1           0.01              1.0
# 38    39           1           0.01              1.0
# 27    40           2           0.02              2.0
# 32    42           1           0.01              1.0
# 5     45           4           0.04              4.0
# 35    46           1           0.01              1.0
# 37    47           1           0.01              1.0
# 1     48           5           0.05              5.0
# 40    49           1           0.01              1.0
# 36    50           1           0.01              1.0
# 7     51           3           0.03              3.0
# 22    52           2           0.02              2.0
# 19    53           2           0.02              2.0
# 26    54           2           0.02              2.0
# 43    56           1           0.01              1.0
# 16    57           3           0.03              3.0
# 10    58           3           0.03              3.0
# 11    60           3           0.03              3.0
# 34    61           1           0.01              1.0
# 31    62           1           0.01              1.0
# 2     64           5           0.05              5.0
# 39    65           1           0.01              1.0
# 8     67           3           0.03              3.0
# 29    68           1           0.01              1.0
# 9     69           3           0.03              3.0
# 6     70           3           0.03              3.0

# %%
tabla_Frecuencias['Frec Acumulada'] = tabla_Frecuencias['Frecuencia'].cumsum()
tabla_Frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 15    18           3           0.03              3.0               3
# 20    19           2           0.02              2.0               5
# 4     20           4           0.04              4.0               9
# 24    21           2           0.02              2.0              11
# 3     22           4           0.04              4.0              15
# 30    23           1           0.01              1.0              16
# 17    24           2           0.02              2.0              18
# 14    25           3           0.03              3.0              21
# 18    26           2           0.02              2.0              23
# 41    28           1           0.01              1.0              24
# 13    29           3           0.03              3.0              27
# 23    30           2           0.02              2.0              29
# 0     31           6           0.06              6.0              35
# 33    32           1           0.01              1.0              36
# 25    33           2           0.02              2.0              38
# 21    34           2           0.02              2.0              40
# 28    35           2           0.02              2.0              42
# 12    36           3           0.03              3.0              45
# 42    38           1           0.01              1.0              46
# 38    39           1           0.01              1.0              47
# 27    40           2           0.02              2.0              49
# 32    42           1           0.01              1.0              50
# 5     45           4           0.04              4.0              54
# 35    46           1           0.01              1.0              55
# 37    47           1           0.01              1.0              56
# 1     48           5           0.05              5.0              61
# 40    49           1           0.01              1.0              62
# 36    50           1           0.01              1.0              63
# 7     51           3           0.03              3.0              66
# 22    52           2           0.02              2.0              68
# 19    53           2           0.02              2.0              70
# 26    54           2           0.02              2.0              72
# 43    56           1           0.01              1.0              73
# 16    57           3           0.03              3.0              76
# 10    58           3           0.03              3.0              79
# 11    60           3           0.03              3.0              82
# 34    61           1           0.01              1.0              83
# 31    62           1           0.01              1.0              84
# 2     64           5           0.05              5.0              89
# 39    65           1           0.01              1.0              90
# 8     67           3           0.03              3.0              93
# 29    68           1           0.01              1.0              94
# 9     69           3           0.03              3.0              97
# 6     70           3           0.03              3.0             100

# %%
import math
print(edades)
# Out:
# [60, 53, 58, 69, 51, 68, 26, 24, 22, 58, 48, 70, 51, 31, 26, 67, 23, 58, 48, 62, 22, 32, 31, 48, 30, 34, 25, 20, 57, 29, 67, 18, 45, 64, 45, 18, 36, 48, 42, 25, 45, 52, 31, 57, 64, 31, 40, 67, 25, 70, 69, 70, 54, 48, 46, 60, 61, 39, 57, 20, 52, 47, 33, 50, 20, 36, 36, 31, 69, 64, 29, 29, 65, 21, 49, 19, 60, 33, 18, 24, 34, 53, 22, 28, 20, 35, 45, 22, 51, 38, 21, 30, 54, 35, 40, 64, 19, 64, 31, 56]

# %%
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     60
# 1     53
# 2     58
# 3     69
# 4     51
# ..   ...
# 95    64
# 96    19
# 97    64
# 98    31
# 99    56
#
# [100 rows x 1 columns]

# %%
n = len(edades)
k = int(1 + math.log2(n))
print("Valor de n = ", n , " \nNumero de intervalos=", )
# Out:
# Valor de n =  100
# Numero de intervalos = 7

# %%
tabla_Frecuencia = pd.cut(df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_Frecuencia.columns = ['Clase', 'Frec']
tabla_Frecuencia
# Out:
#               Clase  Frec
# 0  (17.947, 25.429]    21
# 1    (62.571, 70.0]    16
# 2  (47.714, 55.143]    16
# 3  (25.429, 32.857]    15
# 4  (32.857, 40.286]    13
# 5  (55.143, 62.571]    12
# 6  (40.286, 47.714]     7

# %%
tabla_Frecuencia = tabla_Frecuencia.sort_values(by='Clase')
tabla_Frecuencia
# Out:
#               Clase  Frec
# 0  (17.947, 25.429]    21
# 3  (25.429, 32.857]    15
# 4  (32.857, 40.286]    13
# 6  (40.286, 47.714]     7
# 2  (47.714, 55.143]    16
# 5  (55.143, 62.571]    12
# 1    (62.571, 70.0]    16

# %%
tabla_Frecuencia['Frec Rel'] = tabla_Frecuencia['Frec'] / n
tabla_Frecuencia['Frec porc'] = tabla_Frecuencia['Frec'] / n * 100
tabla_Frecuencia['Frec Ac'] = tabla_Frecuencia['Frec'].cumsum()
tabla_Frecuencia['Frec Rel Ac'] = tabla_Frecuencia['Frec Rel'].cumsum()
tabla_Frecuencia['Frec porc Ac'] = tabla_Frecuencia['Frec porc'].cumsum()
display(tabla_Frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec porc  Frec Ac  Frec Rel Ac  \
# 0  (17.947, 25.429]    21      0.21       21.0       21         0.21
# 3  (25.429, 32.857]    15      0.15       15.0       36         0.36
# 4  (32.857, 40.286]    13      0.13       13.0       49         0.49
# 6  (40.286, 47.714]     7      0.07        7.0       56         0.56
# 2  (47.714, 55.143]    16      0.16       16.0       72         0.72
# 5  (55.143, 62.571]    12      0.12       12.0       84         0.84
# 1    (62.571, 70.0]    16      0.16       16.0      100         1.00
#
#    Frec porc Ac
# 0          21.0
# 3          36.0
# 4          49.0
# 6          56.0
# 2          72.0
# 5          84.0
# 1         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion mathplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion mathplotlib con valores estandar')
