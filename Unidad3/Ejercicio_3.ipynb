# %% [markdown]
# <a href="https://colab.research.google.com/github/BeltranCristian/probabilidad/blob/main/Unidad3/Ejercicio_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Datos
x = np.array([0, 1, 2, 3, 4, 5])
p = np.array([0.05, 0.10, 0.25, 0.30, 0.20, 0.10])

# 1. Verificar suma de probabilidades
print("Suma de probabilidades:", np.sum(p))

# 2. Distribución de probabilidad
dist = pd.DataFrame({'X (unidades vendidas)': x, 'P(X)': p})
print(dist)

# 3. Cálculos
E_X = np.sum(x * p)
Var_X = np.sum(((x - E_X) ** 2) * p)
Desv_X = np.sqrt(Var_X)

print(f"Valor esperado E[X]: {E_X:.2f}")
print(f"Varianza Var(X): {Var_X:.2f}")
print(f"Desviación estándar: {Desv_X:.2f}")

# 4. Función de distribución acumulada
F = np.cumsum(p)
dist['F(x)'] = F
print(dist)

plt.step(x, F, where='post')
plt.title('Función de Distribución Acumulada F(x) - Ventas Semanales')
plt.xlabel('Unidades vendidas (X)')
plt.ylabel('F(x)')
plt.grid(True)
plt.show()

# 5. Interpretación
print("\nInterpretación:")
print(f"Se espera vender {E_X:.2f} unidades por semana.")
print("Una desviación estándar baja indica demanda estable, una alta indica variabilidad.")
# Out:
# Suma de probabilidades: 0.9999999999999999
#    X (unidades vendidas)  P(X)
# 0                      0  0.05
# 1                      1  0.10
# 2                      2  0.25
# 3                      3  0.30
# 4                      4  0.20
# 5                      5  0.10
# Valor esperado E[X]: 2.80
# Varianza Var(X): 1.66
# Desviación estándar: 1.29
#    X (unidades vendidas)  P(X)  F(x)
# 0                      0  0.05  0.05
# 1                      1  0.10  0.15
# 2                      2  0.25  0.40
# 3                      3  0.30  0.70
# 4                      4  0.20  0.90
# 5                      5  0.10  1.00
# Interpretación:
# Se espera vender 2.80 unidades por semana.
# Una desviación estándar baja indica demanda estable, una alta indica variabilidad.
